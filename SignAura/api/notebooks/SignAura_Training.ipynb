# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (25.12.19)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.15.1)
# Requirement already satisfied: jax>=0.3.15 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.30)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (18.1.1)
# Collecting numpy<1.24,>=1.22 (from tensorflow-intel==2.12.0->tensorflow)
#   Using cached numpy-1.23.5-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.25.8)
# Requirement already satisfied: setuptools in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel>=0.26 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.45.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.6.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.5.4)
# Requirement already satisfied: scipy>=1.9 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.15.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\acer\onedrive\desktop\signaura project\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.0.3)
# Using cached numpy-1.23.5-cp311-cp311-win_amd64.whl (14.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.3.3 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# scikit-learn 1.8.0 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
import pickle
import os
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy

# %%
path = "train_data.csv"

df = pd.read_csv(path, low_memory=False)

# %%
path="test_data.csv"
df = pd.read_csv(path)

# %%
# ---------------- LOAD TRAIN & TEST CSV ----------------
train_df = pd.read_csv("train_data.csv", low_memory=False)
test_df  = pd.read_csv("test_data.csv", low_memory=False)

print("Train CSV:", train_df.shape)
print("Test CSV:", test_df.shape)
# Out:
# Train CSV: (30568, 64)
# Test CSV: (5731, 64)

# %%
train_df.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30563    0
# 30564    0
# 30565    0
# 30566    0
# 30567    0
# Length: 30568, dtype: int64

# %%
train_df[:1].dtypes
# Out:
# x0        object
# y0        object
# z0        object
# x1        object
# y1        object
#            ...
# z19       object
# x20       object
# y20       object
# z20       object
# folder    object
# Length: 64, dtype: object

# %%
train_df.head()
# Out:
#             x0           y0         z0           x1           y1  \
# 0  0.449241579   0.64415729  -9.04e-08  0.429074943  0.635371089
# 1  0.382245362  0.558267474   7.06E-08  0.413395762  0.533815086
# 2  0.452943265  0.621691525  -6.09E-08  0.468021393  0.626518607
# 3  0.781940937  0.525786042  -7.77e-08  0.779762387  0.499152124
# 4  0.430419564  0.846907556   2.84e-08  0.470211208  0.821797192
#
#              z1           x2           y2            z2           x3  ...  \
# 0   0.003722572  0.408368379   0.63087821   0.002986991  0.392120898  ...
# 1   0.000568241  0.427210212  0.506034136  -0.001061654  0.434977144  ...
# 2   0.001431449  0.479241788  0.636463523   0.001262602  0.485580653  ...
# 3    0.00450749  0.768690765  0.475780934   0.003003466  0.754124761  ...
# 4  -0.011500387  0.520999908  0.802827656  -0.025803007   0.56479913  ...
#
#            x18          y18           z18          x19          y19  \
# 0  0.391990364  0.655341327  -0.015527404  0.383398265  0.662171423
# 1  0.402409852  0.479038984  -0.034060862  0.406095743  0.463534415
# 2  0.449999154  0.665923119  -0.004571089  0.451644897  0.666010082
# 3  0.726171911  0.491400063  -0.025716092  0.730468273  0.498696953
# 4  0.503666461  0.881531835  -0.076967724  0.514606178  0.897112548
#
#             z19          x20          y20           z20  \
# 0  -0.015240635   0.37765485  0.669068992  -0.015004144
# 1  -0.036735639  0.409117639  0.449920237  -0.038406786
# 2  -0.001769416  0.451801866  0.662505746   0.000665507
# 3  -0.021514077  0.739267945   0.50162214  -0.017493377
# 4  -0.074608542   0.51725775  0.908199072  -0.070945479
#
#                              folder
# 0                Whom|කාටද|யாருக்கு
# 1        Ayubowan|ආයුබෝවන්|ஆயுபோவன்
# 2                       Bag|බෑගය|பை
# 3  I know|මම දන්නවා|எனக்கு தெரியும்
# 4                  Tell|කියන්න|சொல்
#
# [5 rows x 64 columns]

# %%
X_train = train_df.drop("folder", axis=1)
y_train = train_df["folder"]

X_test = test_df.drop("folder", axis=1)
y_test = test_df["folder"]

# %%
X_train = X_train.apply(pd.to_numeric,errors="coerce")
X_test = X_test.apply(pd.to_numeric,errors="coerce")

# %%
X_test[:1].dtypes
# Out:
# x0     float64
# y0     float64
# z0     float64
# x1     float64
# y1     float64
#         ...
# y19    float64
# z19    float64
# x20    float64
# y20    float64
# z20    float64
# Length: 63, dtype: object

# %%
X_train[:1].dtypes
# Out:
# x0     float64
# y0     float64
# z0     float64
# x1     float64
# y1     float64
#         ...
# y19    float64
# z19    float64
# x20    float64
# y20    float64
# z20    float64
# Length: 63, dtype: object

# %%
X_train.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30563    0
# 30564    0
# 30565    0
# 30566    0
# 30567    0
# Length: 30568, dtype: int64

# %%
np.isnan(X_train).sum()
# Out:
# x0     1
# y0     1
# z0     1
# x1     1
# y1     1
#       ..
# y19    1
# z19    1
# x20    1
# y20    1
# z20    1
# Length: 63, dtype: int64

# %%
mask = X_train.notna().all(axis=1)

X_train = X_train.loc[mask]
y_train = y_train.loc[mask]

# %%
X_test[:5]
# Out:
#          x0        y0            z0        x1        y1        z1        x2  \
# 0  0.441752  0.450380  1.790000e-07  0.461223  0.417520  0.001214  0.460240
# 1  0.759249  0.559344 -1.060000e-07  0.721400  0.551557 -0.000053  0.682172
# 2  0.423867  0.686609  1.230000e-07  0.437681  0.666430 -0.005854  0.458200
# 3  0.358600  0.724326 -1.590000e-07  0.343545  0.709470 -0.003469  0.319427
# 4  0.578133  0.641648  4.540000e-07  0.557434  0.589512  0.007384  0.542337
#
#          y2        z2        x3  ...       z17       x18       y18       z18  \
# 0  0.383041  0.003527  0.456155  ... -0.010446  0.447635  0.374299 -0.015479
# 1  0.566878 -0.001861  0.658565  ... -0.021716  0.724178  0.640497 -0.022249
# 2  0.662696 -0.008692  0.476785  ... -0.008212  0.480583  0.714617 -0.010361
# 3  0.695936 -0.007574  0.297728  ... -0.021964  0.298440  0.718010 -0.029165
# 4  0.546912  0.005396  0.529377  ... -0.031387  0.502241  0.552534 -0.034357
#
#         x19       y19       z19       x20       y20       z20
# 0  0.450875  0.360810 -0.016933  0.454070  0.349162 -0.017693
# 1  0.729266  0.632614 -0.015970  0.735672  0.623266 -0.011545
# 2  0.492978  0.717287 -0.010956  0.502658  0.719305 -0.010956
# 3  0.285947  0.725180 -0.031624  0.276931  0.732808 -0.032822
# 4  0.492158  0.528080 -0.034953  0.483088  0.508008 -0.036459
#
# [5 rows x 63 columns]

# %%
y_train[:5]
# Out:
# 0                  Whom|කාටද|யாருக்கு
# 1          Ayubowan|ආයුබෝවන්|ஆயுபோவன்
# 2                         Bag|බෑගය|பை
# 3    I know|මම දන්නවා|எனக்கு தெரியும்
# 4                    Tell|කියන්න|சொல்
# Name: folder, dtype: object

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

ENCODER_FILE = "label_encoder_382.pkl"
with open(ENCODER_FILE, "wb") as f:
    pickle.dump(label_encoder, f)

print(f"✅ Labels encoded and saved to '{ENCODER_FILE}'")
# Out:
# ✅ Labels encoded and saved to 'label_encoder_382.pkl'

# %%
y_train_encoded[:5]
# Out:
# array([365,  12,  15, 158, 316])

# %%
len(label_encoder.classes_)
# Out:
# 381

# %%
# ---------------- BUILD MODEL ----------------
model = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.0),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.0),
    layers.Dense(32, activation='relu'),
    layers.Dense(len(label_encoder.classes_), activation='softmax')
])

# ---------- OPTIMIZER ----------
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ---------------- CALLBACKS ----------------
checkpoint = ModelCheckpoint(
    filepath='Round_09/{epoch:02d}_accuracy_{val_accuracy:.4f}.keras',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=120,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=30,
    min_lr=1e-6,
    verbose=1
)

# ---------------- TRAIN ----------------
history = model.fit(
    X_train, y_train_encoded,
    validation_split=0.1,
    epochs=450,
    batch_size=32,
    callbacks=[checkpoint, early_stop, reduce_lr],
    shuffle=True,
)
# Out:
# Epoch 1/450
# 855/860 [============================>.] - ETA: 0s - loss: 5.6120 - accuracy: 0.0106
# Epoch 1: val_accuracy improved from -inf to 0.01603, saving model to Round_09\01_accuracy_0.0160.keras
# 860/860 [==============================] - 6s 5ms/step - loss: 5.6096 - accuracy: 0.0108 - val_loss: 5.3456 - val_accuracy: 0.0160 - lr: 0.0010
# Epoch 2/450
# 848/860 [============================>.] - ETA: 0s - loss: 5.2213 - accuracy: 0.0249
# Epoch 2: val_accuracy improved from 0.01603 to 0.02781, saving model to Round_09\02_accuracy_0.0278.keras
# 860/860 [==============================] - 4s 4ms/step - loss: 5.2190 - accuracy: 0.0251 - val_loss: 5.1278 - val_accuracy: 0.0278 - lr: 0.0010
# Epoch 3/450
# 851/860 [============================>.] - ETA: 0s - loss: 4.8822 - accuracy: 0.0551
# Epoch 3: val_accuracy improved from 0.02781 to 0.08374, saving model to Round_09\03_accuracy_0.0837.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 4.8818 - accuracy: 0.0552 - val_loss: 4.6741 - val_accuracy: 0.0837 - lr: 0.0010
# Epoch 4/450
# 857/860 [============================>.] - ETA: 0s - loss: 4.4924 - accuracy: 0.0962
# Epoch 4: val_accuracy improved from 0.08374 to 0.12332, saving model to Round_09\04_accuracy_0.1233.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 4.4919 - accuracy: 0.0963 - val_loss: 4.3365 - val_accuracy: 0.1233 - lr: 0.0010
# Epoch 5/450
# 853/860 [============================>.] - ETA: 0s - loss: 4.2452 - accuracy: 0.1233
# Epoch 5: val_accuracy improved from 0.12332 to 0.12954, saving model to Round_09\05_accuracy_0.1295.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 4.2464 - accuracy: 0.1231 - val_loss: 4.2340 - val_accuracy: 0.1295 - lr: 0.0010
# Epoch 6/450
# 846/860 [============================>.] - ETA: 0s - loss: 4.0932 - accuracy: 0.1430
# Epoch 6: val_accuracy improved from 0.12954 to 0.14720, saving model to Round_09\06_accuracy_0.1472.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 4.0914 - accuracy: 0.1436 - val_loss: 4.0434 - val_accuracy: 0.1472 - lr: 0.0010
# Epoch 7/450
# 848/860 [============================>.] - ETA: 0s - loss: 3.9673 - accuracy: 0.1585
# Epoch 7: val_accuracy improved from 0.14720 to 0.16683, saving model to Round_09\07_accuracy_0.1668.keras
# 860/860 [==============================] - 4s 4ms/step - loss: 3.9660 - accuracy: 0.1585 - val_loss: 3.9224 - val_accuracy: 0.1668 - lr: 0.0010
# Epoch 8/450
# 855/860 [============================>.] - ETA: 0s - loss: 3.8580 - accuracy: 0.1713
# Epoch 8: val_accuracy improved from 0.16683 to 0.18090, saving model to Round_09\08_accuracy_0.1809.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.8570 - accuracy: 0.1716 - val_loss: 3.8315 - val_accuracy: 0.1809 - lr: 0.0010
# Epoch 9/450
# 848/860 [============================>.] - ETA: 0s - loss: 3.7786 - accuracy: 0.1819
# Epoch 9: val_accuracy improved from 0.18090 to 0.18155, saving model to Round_09\09_accuracy_0.1816.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.7746 - accuracy: 0.1823 - val_loss: 3.7969 - val_accuracy: 0.1816 - lr: 0.0010
# Epoch 10/450
# 842/860 [============================>.] - ETA: 0s - loss: 3.7040 - accuracy: 0.1921
# Epoch 10: val_accuracy improved from 0.18155 to 0.19431, saving model to Round_09\10_accuracy_0.1943.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.7021 - accuracy: 0.1921 - val_loss: 3.7370 - val_accuracy: 0.1943 - lr: 0.0010
# Epoch 11/450
# 846/860 [============================>.] - ETA: 0s - loss: 3.6499 - accuracy: 0.1970
# Epoch 11: val_accuracy improved from 0.19431 to 0.19954, saving model to Round_09\11_accuracy_0.1995.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.6505 - accuracy: 0.1975 - val_loss: 3.6841 - val_accuracy: 0.1995 - lr: 0.0010
# Epoch 12/450
# 848/860 [============================>.] - ETA: 0s - loss: 3.6051 - accuracy: 0.2035
# Epoch 12: val_accuracy improved from 0.19954 to 0.20576, saving model to Round_09\12_accuracy_0.2058.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.6040 - accuracy: 0.2034 - val_loss: 3.6593 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 13/450
# 855/860 [============================>.] - ETA: 0s - loss: 3.5555 - accuracy: 0.2125
# Epoch 13: val_accuracy improved from 0.20576 to 0.21917, saving model to Round_09\13_accuracy_0.2192.keras
# 860/860 [==============================] - 3s 4ms/step - loss: 3.5555 - accuracy: 0.2124 - val_loss: 3.6140 - val_accuracy: 0.2192 - lr: 0.0010
# Epoch 14/450
# 848/860 [============================>.] - ETA: 0s - loss: 3.5049 - accuracy: 0.2208
# Epoch 14: val_accuracy improved from 0.21917 to 0.23225, saving model to Round_09\14_accuracy_0.2323.keras
# 860/860 [==============================] - 3s 3ms/step - loss: 3.5047 - accuracy: 0.2212 - val_loss: 3.5236 - val_accuracy: 0.2323 - lr: 0.0010
# Epoch 15/450
# 857/860 [============================>.] - ETA: 0s - loss: 3.4688 - accuracy: 0.2286
# Epoch 15: val_accuracy did not improve from 0.23225
# 860/860 [==============================] - 2s 3ms/step - loss: 3.4689 - accuracy: 0.2285 - val_loss: 3.5500 - val_accuracy: 0.2323 - lr: 0.0010
# Epoch 16/450
# 848/860 [============================>.] - ETA: 0s - loss: 3.4208 - accuracy: 0.2387
# Epoch 16: val_accuracy improved from 0.23225 to 0.23749, saving model to Round_09\16_accuracy_0.2375.keras
# 860/860 [==============================] - 3s 4ms/step - loss: 3.4206 - accuracy: 0.2388 - val_loss: 3.4738 - val_accuracy: 0.2375 - lr: 0.0010
# Epoch 17/450
# 855/860 [============================>.] - ETA: 0s - loss: 3.3707 - accuracy: 0.2452
# Epoch 17: val_accuracy improved from 0.23749 to 0.27151, saving model to Round_09\17_accuracy_0.2715.keras
# 860/860 [==============================] - 3s 4ms/step - loss: 3.3703 - accuracy: 0.2455 - val_loss: 3.4008 - val_accuracy: 0.2715 - lr: 0.0010
# Epoch 18/450
# 857/860 [============================>.] - ETA: 0s - loss: 3.3198 - accuracy: 0.2552
# Epoch 18: val_accuracy did not improve from 0.27151
# 860/860 [==============================] - 3s 3ms/step - loss: 3.3186 - accuracy: 0.2553 - val_loss: 3.4579 - val_accuracy: 0.2506 - lr: 0.0010
# Epoch 19/450
# 854/860 [============================>.] - ETA: 0s - loss: 3.2519 - accuracy: 0.2686

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 128)               8192
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dense_27 (Dense)            (None, 381)               12573
#
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ---------------- EVALUATE ----------------
loss, acc = model.evaluate(X_test, y_test_encoded, verbose=1)
print(f"\nTest Accuracy: {acc:.4f}")
# Out:
# 180/180 [==============================] - 1s 3ms/step - loss: 3.3375 - accuracy: 0.8027
#
# Test Accuracy: 0.8027

# %%
# ---------- EVALUATE MODEL ----------
test_loss, test_acc = model.evaluate(X_test, y_test_encoded, verbose=1)

print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 180/180 [==============================] - 0s 2ms/step - loss: 3.3375 - accuracy: 0.8027
# Test Accuracy: 0.8027
# Test Loss: 3.3375

# %%
predicts = model.predict(X_test)
# Out:
# 180/180 [==============================] - 1s 2ms/step

# %%
X_test[:5]
# Out:
# array([[-0.31955782, -1.36518945,  0.96800579, -0.21289389, -1.51039442,
#          0.7101578 , -0.23415137, -1.62275122,  1.0781816 , -0.2695505 ,
#         -1.66240605,  1.21181543, -0.26121735, -1.70676598,  1.2559884 ,
#         -0.36564914, -1.52750306,  1.34301595, -0.34586189, -1.53734653,
#          1.15763052, -0.31450037, -1.61730443,  0.95559548, -0.28709409,
#         -1.68483237,  0.78600577, -0.3788169 , -1.52275355,  1.22069059,
#         -0.35318475, -1.59019862,  1.02244744, -0.30930329, -1.71320104,
#          0.78056132, -0.27016179, -1.81582676,  0.59305184, -0.36057762,
#         -1.51518914,  0.92056718, -0.33296876, -1.59473913,  0.72280413,
#         -0.29333075, -1.70488747,  0.48061505, -0.26206038, -1.79176791,
#          0.30052605, -0.31729205, -1.49873188,  0.56066364, -0.30775157,
#         -1.55349132,  0.42572481, -0.28648949, -1.62877446,  0.26003058,
#         -0.26302867, -1.68790864,  0.12533503],
#        [ 1.6967636 , -0.37586805, -0.95474742,  1.50139498, -0.30540793,
#          0.53552344,  1.26317501, -0.04950558,  0.58386844,  1.1034946 ,
#          0.15252308,  0.66726912,  1.08797016,  0.32249965,  0.68000587,
#          1.24919733,  0.1351683 , -0.33599214,  1.17179349,  0.4297999 ,
#         -0.22894176,  1.19736798,  0.36229878, -0.13331229,  1.21661837,
#          0.26740933, -0.04492073,  1.3762739 ,  0.19311937, -0.40297969,
#          1.29066488,  0.42560228, -0.09492744,  1.32546971,  0.34945892,
#          0.13940901,  1.36378952,  0.26117861,  0.22462524,  1.49735446,
#          0.22827137, -0.36016316,  1.41487936,  0.40780777, -0.0148109 ,
#          1.44541117,  0.33602706,  0.31457419,  1.47922913,  0.25552478,
#          0.43639717,  1.59977867,  0.24540618, -0.25823345,  1.50800496,
#          0.39024675,  0.01703022,  1.54134874,  0.32758342,  0.31601368,
#          1.57667717,  0.26038162,  0.46829868],
#        [-0.43314508,  0.77960605,  0.59020165, -0.3680124 ,  0.72729081,
#         -0.26437383, -0.24791319,  0.77048092, -0.04272232, -0.12960467,
#          0.81674477,  0.19629604, -0.03613968,  0.80962131,  0.35768846,
#         -0.16484069,  0.93008776, -0.09092189, -0.0108101 ,  0.97831499,
#          0.14973052,  0.08175512,  0.99464573,  0.30133793,  0.15234255,
#          1.0062604 ,  0.39971391, -0.17356255,  0.95901145,  0.19167708,
#         -0.01196251,  0.97485043,  0.38457277,  0.10283935,  0.98068289,
#          0.4398956 ,  0.19136942,  0.98998512,  0.45923073, -0.18773436,
#          0.95577683,  0.49708575, -0.04041451,  0.95676609,  0.60154494,
#          0.06668672,  0.96224194,  0.49242684,  0.14870313,  0.97243661,

#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.20767757e-15, 1.59567222e-31, 0.00000000e+00,
#         4.63975382e-26, 2.18311767e-28, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.71769113e-06, 0.00000000e+00, 3.93728238e-21,
#         4.11689341e-23, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.00822134e-31,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.74716998e-14,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4.86999927e-24, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.64586194e-16, 0.00000000e+00, 0.00000000e+00, 2.08908221e-28,
#         0.00000000e+00, 7.40748941e-27, 9.07238550e-34, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.26202804e-30, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 9.18851377e-25, 0.00000000e+00, 1.58532335e-36,
#         0.00000000e+00, 9.22146086e-23, 0.00000000e+00, 0.00000000e+00,
#         3.41942039e-17, 2.83707178e-24, 0.00000000e+00, 1.53276919e-10,
#         0.00000000e+00, 3.85007235e-19, 2.44710282e-06, 3.19107196e-31,
#         0.00000000e+00, 3.87431960e-28, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.77899095e-34, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.09389897e-14, 0.00000000e+00,
#         0.00000000e+00]], dtype=float32)

# %%
y_pred_classes = np.argmax(predicts, axis=1)

# %%
y_pred_classes[:5]
# Out:
# array([163, 201, 361,  88,  63], dtype=int64)

# %%
y_pred_decode = label_encoder.inverse_transform(y_pred_classes)

# %%
test_df["pred"]= y_pred_decode

# %%
test_df.to_csv("new_output_qwe.csv", index=False)

# %%
savedModel = tf.keras.models.load_model("model.keras")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 savedModel = tf.keras.models.load_model("model.keras")
#
# File c:\Users\Acer\OneDrive\Desktop\Signaura project\venv\Lib\site-packages\keras\src\saving\saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)    220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=model.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
savedModel.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 128)               8192
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dense_23 (Dense)            (None, 381)               12573
#
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds = savedModel.predict(X_test)
# Out:
# 180/180 [==============================] - 1s 3ms/step

# %%
preds[:5]
# Out:
# array([[0.0000000e+00, 1.1952403e-12, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.8146254e-37, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 6.5574077e-06, 2.2856662e-19, ..., 1.2008936e-09,
#         2.0190686e-37, 2.4348173e-10],
#        [1.9500741e-35, 1.0455498e-26, 1.0108445e-27, ..., 0.0000000e+00,
#         0.0000000e+00, 1.1445886e-21],
#        [0.0000000e+00, 2.1988718e-09, 7.8058445e-30, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
y_pred_Num = np.argmax(preds, axis=1)

# %%
y_pred_Num[:5]
# Out:
# array([277, 201, 145,  88, 177], dtype=int64)
